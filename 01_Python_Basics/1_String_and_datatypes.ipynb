# %%
# ----Running my first rogram-----

print("Hello, World!")

# taking input from user
name = (input("Enter your name: "))
print("Hello", name)


# Write code that displays user's favorite color

fav_color = (input("Enter your favorite color: "))
print("Youe favourite color is: ", fav_color)
# Out:
# Hello, World!
# Hello sana
# Youe favourite color is:  sky

# %%
# ---Data in python---
# strings 
# A string is a sequence of characters (text) written inside quotes.
str = "London"
print(str)

print("HTML"+" "+"CSS")

print("11234")

print("""Hello, World!
      It's great to be here!""")

str1 = 'this is string.\n and creating it'
print(str1)

#to add two strings
str1 = "mehwish"
str2 = "bashir"
print(str1 + str2)


# to repeat a string
s = "abc"
print(s * 3)
# Out:
# London
# HTML CSS
# 11234
# Hello, World!
#       It's great to be here!
# this is string.
#  and creating it
# mehwishbashir
# abcabcabc

# %%
# data types
# A data type tells Python what kind of value a variable contains.

num = 33.9
print(type(num))

num = int(33.9)
print(type(num))

str = "Python is a user friendly language"
print(type(str))

marks = 95
print(type(marks))

is_student = True
print(type(is_student))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'bool'>
