# %%
from helper_functions import print_llm_response

print_llm_response("What is the capital of France?")
# Out:
# The capital of France is **Paris**.

# %%
from helper_functions import print_llm_response
name = "Otto Matic"
dog_age = 21/7
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior in 40 words.""")
# Out:
# At three years old, Otto is a young adult dog in his prime. He has high yet balanced energy and mental maturity. He loves active fetch games, training, and exploring, while demonstrating confident, obedient, and fully settled daily canine behavior.

# %%
driver = "unicorn"
driver_vehicle = "colorful, asymmetric dinosaur car"
favorite_planet = "Pluto"
print_llm_response(f"""Write me a 200 word children's story about a {driver} racing
a {driver_vehicle} for the {favorite_planet} champion cup.""")
# Out:
# The neon lights of Pluto’s Starlight Speedway buzzed with excitement. It was time for the finale of the Pluto Champion Cup!
#
# In lane one stood Barnaby, a dazzling unicorn with a shimmering silver mane. In lane two revved *Dino-Dash*, a wildly colorful, asymmetric dinosaur car. It had a giant T-Rex snout, one oversized monster wheel on the left, three tiny neon wheels on the right, and bright polka-dot scales.
#
# "Three, two, one... GO!" zapped the cosmic flag.
#
# Barnaby galloped forward, leaving a sparkling rainbow trail across the icy track. *Vroom-ROAR!* Dino-Dash wobbled hilariously on its uneven wheels, but its tail-pipe shot out purple bubbles, propelling the quirky car forward at lightning speed.
#
# Up the frosty loop-de-loop they went! Barnaby leaped gracefully over a floating asteroid. Dino-Dash zoomed beneath it, snorting happy clouds of glittery steam.
#
# ...

# %%
# Make variables for your favorite game, movie, and food. # Then use print_llm_response to ask the LLM to recommend you
favorite_game = "Subway surfers"
favorite_movie = "All of us are dead"
favorite_food = "Biryani"

print_llm_response(f"""
I like the following:
- Favorite game: {favorite_game}
- Favorite movie: {favorite_movie}
- Favorite food: {favorite_food}

Based on my likes, recommend a new song for me to listen to.
""")
# Out:
# Based on your mix of fast-paced gaming, high-intensity Korean thriller, and rich, flavorful food, your recommended song is:
#
# ### **"God's Menu" (神메뉴) by Stray Kids**
#
# Here is why this fits your exact taste profile:
#
# * **For *Subway Surfers* (The Pace):** The song has a fast, relentless, high-bpm beat with heavy bass that makes you feel like you're in the middle of a high-speed chase or endless runner game.
# * **For *All of Us Are Dead* (The Vibe):** It’s an intense, aggressive Korean track with dramatic energy, powerful vocals, and a dark, youthful edge that matches the adrenaline of a modern K-drama thriller.
# * **For *Biryani* (The Flavor):** The whole concept of the song revolves around cooking and food metaphors—delivering powerful, rich, unforgettable "flavors" and spice that leave you hooked, much like a good Biryani!
#
# ---
#
# **Bonus Alternative:**
# ...
