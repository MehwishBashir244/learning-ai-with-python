# %%
#
#---arithematic operators---
# Perform mathematical operations.

a = 22
b = 11

print(a+b)
print(a*b)
print(a/b)
print(a**b)


# taking input from user

num1 = int(input("Enter Number: "))
num2 = int(input("Enter Number: "))
sum = num1 + num2
subtraction = num1 - num2
multiply = num1 * num2
print("sum:", sum)
print("subtraction:", subtraction)
print("multiplication:", multiply)


# converting fahrenheit to celsius

fahrenheit = 98.6
celsius = (fahrenheit - 32) * 5 / 9

print("Temperature in celsius:",celsius)


# Write code to convert 6 feet to meters

feet = 6
meters = feet * 0.3048

print("feet in meters:",meters)
# Out:
# 33
# 242
# 2.0
# 584318301411328
# sum: 8
# subtraction: -2
# multiplication: 15
# Temperature in celsius: 37.0
# feet in meters: 1.8288000000000002

# %%
#---relational operators---
# Compare two values.

a = 22
b = 11
print(a==b)
print(a!=b)
print(a<=b)
print(a>=b)
# Out:
# False
# True
# False
# True

# %%
#---assignment operators---
# Assign values to variables.

num = 22
num += 2
print(num)
num -= 2
print(num)
num *= 2
print(num)
num /= 2
print(num)
# Out:
# 24
# 22
# 44
# 22.0

# %%
#---logical operators---
# Combine conditional statements.

a = 22
b = 11
print(not(a >= b))

val1 = True 
val2 = False
print(val1 and val2)
print(val1 or val2)
# Out:
# False
# False
# True
