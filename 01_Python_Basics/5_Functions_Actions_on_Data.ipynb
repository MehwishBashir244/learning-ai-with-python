# %%
from helper_functions import *
print("--/--")
print_llm_response("What is the capital of France?")
# Out:
# --/--
# The capital of France is **Paris**.

# %%
# Functions to count, to round, and to do much more
# len() function counts the characters in a string

print( len("She is a master chef.") ) 
print( len("Hello World!") ) 
print(len("1234"))

str = "i am going to market to buy some fruits."
print(len(str))

str = "i am going to market to buy some fruits."
print(len(str))

str1 = "i am going to market to buy some fruits."
str2 = "and i will be back in 30 minutes."
str3 = str1 +str2
print(len(str3))
# Out:
# 21
# 12
# 4
# 40
# 40
# 73

# %%
# round() to take a floating point number and round it to the nearest integer

print(round(55.17))
num = 88.90
print(round(88.90))
# Out:
# 55
# 89

# %%
from helper_functions import print_llm_response
name = "ali"
potatoes = 4.82
print_llm_response(f"""Write a couplet about my friend {name} who has about {round(potatoes)} potatoes""")
# Out:
# With five fine potatoes tucked safe on his shelf,
# Ali counts his small treasure and smiles to himself.

# %%
# Enter one of your favorite numbers. Multiply the result by 10 and save it to a variable called 'lucky_number'.
# Print a message saying "Your lucky number is [lucky_number]!"

lucky_number = 5*10
print(f"Your lucky number is {lucky_number }!")
# Out:
# Your lucky number is 50!

# %%
# Use print_llm_response() to print a poem with the specified number of lines. Use the prompt variable to save your prompt before calling print_llm_response()

number_of_lines = 18

prompt = f"Write a poem with exactly {number_of_lines} lines."

print_llm_response(prompt)
# Out:
# The golden sun begins its slow descent,
# A quiet calm fills up the fading sky,
# The workday ends, its heavy hours spent,
# As sleepy birds begin to soar and fly.
# The shadows lengthen on the grassy ground,
# And twilight whispers with a gentle sound.
#
# A silver moon ascends its velvet throne,
# While scattered stars ignite the evening air,
# The restless world now pauses, left alone,
# Without a trace of burden or of care.
# A gentle breeze hums softly through the trees,
# And brings a sense of quietude and ease.
#
# So close your eyes and let the night remain,
# Forget the worries that the morning brought,
# Release the lingering sorrow and the pain,
# And rest within the quiet you have sought.
# Sleep deep until the golden dawn shall break,
# And light returns to bid the world awake.
