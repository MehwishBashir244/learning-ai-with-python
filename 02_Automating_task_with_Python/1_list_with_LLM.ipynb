# %%
from helper_functions import print_llm_response, get_llm_response

friends_list = ["Sana", "Ali", "Sara"]
print(friends_list)

prompt = f"""
Write a set of four line birthday poems for my friends {friends_list}. 
The poems should be insipred by the first letter of each friend's name.
"""
print_llm_response(prompt)
# Out:
# ['Sana', 'Ali', 'Sara']
# Here are four-line birthday poems tailored for your friends, inspired by the first letters of their names:
#
# **Sana** (*Inspired by the letter **S** - Sunshine & Sparkle*)
# **S**miles and **s**unshine follow where you go,
# A **s**pecial warmth that sets the world aglow.
# May your day **s**parkle bright in every way,
# Happy Birthday, Sana, have a wonderful day!
#
# ***
#
# **Ali** (*Inspired by the letter **A** - Always & Adventure*)
# **A**lways bringing laughter, energy, and cheer,
# **A**n **a**wesome friend who brightens every year.
# May new **a**dventures bless your path today,
# Wishing you the very best, Ali, on your birthday!
#
# ***
#
# **Sara** (*Inspired by the letter **S** - Star & Sweetness*)
# **S**oaring like a **s**tar up in the night,
# Your **s**weet and gentle spirit brings delight.
# May **s**uccess and joy attend all that you do,
# Happy Birthday, Sara, a wonderful year to you!

# %%
list_of_tasks = [
    "Compose a brief email to my boss explaining that I will be late for tomorrow's meeting.",
    "Write a birthday poem for Sana, celebrating his 28th birthday.",
    "Write a 150-word review of the movie 'All of us are dead'."
]
print(list_of_tasks)
# Out:
# ["Compose a brief email to my boss explaining that I will be late for tomorrow's meeting.", 'Write a birthday poem for Sana, celebrating his 28th birthday.', "Write a 150-word review of the movie 'All of us are dead'."]

# %%
task = list_of_tasks[0]
print_llm_response(task)
# Out:
# Subject: Running late for tomorrow's [Meeting Name] - [Your Name]
#
# Hi [Boss's Name],
#
# I am writing to let you know that I will be late for tomorrow’s [Meeting Name] at [Meeting Time] due to [brief reason, e.g., a prior appointment / an unavoidable conflict].
#
# I expect to be about [Number] minutes late and should be able to join by [Estimated Arrival Time]. I have reviewed the agenda and will jump in as soon as I arrive.
#
# Apologies for the inconvenience, and thank you for understanding.
#
# Best,
#
# [Your Name]

# %%
task = list_of_tasks[1]
print_llm_response(task)
# Out:
# Raise a glass and shout hooray,
# For Sana’s twenty-eighth today!
# A special milestone in the sun,
# A bright new chapter has begun.
#
# Through every year that’s come and gone,
# You’ve greeted life with strength like dawn.
# With steady heart and brilliant mind,
# A finer man is hard to find.
#
# At twenty-eight, you’re in your prime,
# A truly memorable time,
# Where grandest dreams begin to bloom,
# And laughter lights up every room.
#
# So here’s a toast to Sana’s year,
# Filled with success and warmth and cheer.
# May health and happiness align,
# To make your twenty-eighth divine!
#
# **Happy 28th Birthday, Sana!**

# %%
task = list_of_tasks[2]
print_llm_response(task)
# Out:
# *All of Us Are Dead* revitalizes the zombie genre by dropping a hyper-violent outbreak directly into the high-stakes environment of a South Korean high school. When a science experiment goes horribly wrong, a group of trapped students must use their wits, makeshift weapons, and fragile bonds to survive hordes of fast, unrelenting undead.
#
# What sets the series apart is its kinetic direction and inventive action sequences—turning everyday classrooms, libraries, and science labs into claustrophobic battlegrounds. Beyond the gory thrills, the show anchors itself in genuine emotional drama, deeply exploring themes of friendship, bullying, and the tragic failure of adults to protect the youth.
#
# While the long runtime occasionally drags with secondary subplots, the relentless pacing, memorable characters, and terrifying "half-zombie" twist keep the overall tension sky-high. Energetic, emotional, and intensely brutal, *All of Us Are Dead* is a thrilling, binge-worthy addition to Korean horror that leaves a lasting bite.
