# %%
from helper_functions import print_llm_response
list_of_tasks = [
    "Compose a brief email to my boss explaining that I will be late for tomorrow's meeting.",
    "Write a birthday poem for Otto, celebrating his 28th birthday.",
    "Write a 300-word review of the movie 'The Arrival'.",
    "Draft a thank-you note for my neighbor Dapinder who helped water my plants while I was on vacation.",
    "Create an outline for a presentation on the benefits of remote work."
]
print(list_of_tasks)
# Out:
# ["Compose a brief email to my boss explaining that I will be late for tomorrow's meeting.", 'Write a birthday poem for Otto, celebrating his 28th birthday.', "Write a 300-word review of the movie 'The Arrival'.", 'Draft a thank-you note for my neighbor Dapinder who helped water my plants while I was on vacation.', 'Create an outline for a presentation on the benefits of remote work.']

# %%
#instead of that unorganized large list, divide tasks by priority
high_priority_tasks = [
    "Compose a brief email to my boss explaining that I will be late for tomorrow's meeting.",
    "Create an outline for a presentation on the benefits of remote work."]

medium_priority_tasks = [
    "Write a birthday poem for Otto, celebrating his 28th birthday.",
    "Draft a thank-you note for my neighbor Dapinder who helped water my plants while I was on vacation."]

low_priority_tasks = [
    "Write a 300-word review of the movie 'The Arrival'."]

# now making dictionary
prioritized_tasks = {
    "high_priority": high_priority_tasks,
    "medium_priority": medium_priority_tasks,
    "low_priority": low_priority_tasks
}

print(prioritized_tasks)
# Out:
# {'high_priority': ["Compose a brief email to my boss explaining that I will be late for tomorrow's meeting.", 'Create an outline for a presentation on the benefits of remote work.'], 'medium_priority': ['Write a birthday poem for Otto, celebrating his 28th birthday.', 'Draft a thank-you note for my neighbor Dapinder who helped water my plants while I was on vacation.'], 'low_priority': ["Write a 300-word review of the movie 'The Arrival'."]}

# %%
for task in prioritized_tasks["high_priority"]:
    print_llm_response(task)
# Out:
# ____________________________________________________________________________________________________
# Subject: Late Arrival for Tomorrow’s Meeting
#
# Hi [Boss’s Name],
#
# I wanted to let you know that I will be late for tomorrow’s meeting due to [brief reason, if you want]. I’ll join as soon as I can.
#
# Thanks for understanding,
# [Your Name]
# ____________________________________________________________________________________________________
#
#
# ____________________________________________________________________________________________________
# I. Introduction
#    A. Definition of remote work
#    B. Growing trend and relevance
#
# II. Benefits for Employees
#    A. Flexibility and work-life balance
#    B. Reduced commuting time and costs
#    C. Increased productivity and focus
#    D. Improved mental health and job satisfaction
#
# III. Benefits for Employers
#    A. Access to a wider talent pool
#    B. Reduced overhead and office costs
#    C. Higher employee retention and engagement
#    D. Enhanced business continuity and resilience
#
# IV. Environmental and Societal Benefits
#    A. Lower carbon footprint due to less commuting
#    B. Reduced traffic congestion
#    C. Support for diverse and inclusive workforces
#
# V. Challenges and Solutions
#    A. Communication and collaboration tools
#    B. Maintaining company culture
#    C. Managing remote teams effectively
#
# VI. Conclusion
#    A. Summary of key benefits
#    B. Future outlook of remote work
#    C. Call to action or recommendations
# ____________________________________________________________________________________________________

# %%
# Complete the medium priority tasks
for task in prioritized_tasks["medium_priority"]:
    print_llm_response(task)
# Out:
# ____________________________________________________________________________________________________
# Happy 28th, dear Otto, today’s your special cheer,
# A year of growth and laughter, another bright new year.
# May joy and dreams surround you, success be in your sight,
# Here’s to health and happiness, and days forever bright!
# ____________________________________________________________________________________________________
#
#
# ____________________________________________________________________________________________________
# Dear Dapinder,
#
# Thank you so much for watering my plants while I was on vacation. I really appreciate your help and kindness.
#
# Best,
# [Your Name]
# ____________________________________________________________________________________________________
