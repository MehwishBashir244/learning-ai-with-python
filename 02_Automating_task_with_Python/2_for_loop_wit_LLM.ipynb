# %%
from helper_functions import print_llm_response, get_llm_response
list_of_tasks = [
    "Compose a 10 words greeting letter",
    "Write a 50-word review of the movie 'Big hero 6'."
]
for task in list_of_tasks:
    print_llm_response(task)
# Out:
# ____________________________________________________________________________________________________
# Dear Friend,
# Wishing you joy, health, and success in all endeavors.
# ____________________________________________________________________________________________________
#
#
# ____________________________________________________________________________________________________
# Big Hero 6 is a heartwarming, action-packed animated film blending humor, friendship, and technology. Its vibrant visuals and lovable characters, especially Baymax, create an emotional journey about loss and teamwork. The story balances excitement with meaningful messages, making it enjoyable for both kids and adults alike. Highly recommended.
# ____________________________________________________________________________________________________

# %%
from helper_functions import print_llm_response, get_llm_response
ice_cream_flavors = ["Vanilla", "Chocolate"]
for flavor in ice_cream_flavors:
    prompt = f"""For the ice cream flavor listed below, 
    provide a captivating description that could be used for promotional purposes.Flavor: {flavor}"""
    print_llm_response(prompt)
# Out:
# ____________________________________________________________________________________________________
# Indulge in the timeless elegance of our Vanilla ice cream—creamy, rich, and perfectly balanced with the pure essence of real vanilla beans. A classic treat that delights every palate and pairs beautifully with any dessert.
# ____________________________________________________________________________________________________
#
#
# ____________________________________________________________________________________________________
# Indulge in the rich, velvety embrace of our classic Chocolate ice cream—crafted from the finest cocoa for a deep, decadent flavor that melts smoothly with every bite. Perfect for satisfying your sweetest cravings!
# ____________________________________________________________________________________________________

# %%
promotional_descriptions = []
for flavor in ice_cream_flavors:
    prompt = f"""For the ice cream flavor listed below, 
    provide a captivating description that could be used for promotional purposes.Flavor: {flavor}"""
    
    description = get_llm_response(prompt)
    promotional_descriptions.append(description)
    
    print(promotional_descriptions)
# Out:
# ['Indulge in the timeless elegance of our Vanilla ice cream—creamy, rich, and perfectly sweetened with the finest vanilla beans. A classic treat that delights every palate and pairs beautifully with any dessert.']
# ['Indulge in the timeless elegance of our Vanilla ice cream—creamy, rich, and perfectly sweetened with the finest vanilla beans. A classic treat that delights every palate and pairs beautifully with any dessert.', 'Indulge in the rich, velvety embrace of our classic Chocolate ice cream—crafted from the finest cocoa for a deep, decadent flavor that melts smoothly with every bite. Perfect for satisfying your sweetest cravings!']

# %%
# Translate the flavors in ice_cream_flavors to Spanish

ice_cream_flavors = ["Vanilla", "Strawberry"]

for flavor in ice_cream_flavors:
    prompt = f"""For the ice cream flavor listed below, translate it to Spanish.Ice cream flavor: {flavor}""" 

    print_llm_response(prompt)
# Out:
# ____________________________________________________________________________________________________
# Sabor de helado: Vainilla
# ____________________________________________________________________________________________________
#
#
# ____________________________________________________________________________________________________
# Sabor de helado: Fresa
# ____________________________________________________________________________________________________

# %%
#  Write code to get a list with words without typos

words_with_typos = ["Aple", "Wether", "Newpaper"]
words_without_typos = []

for word in words_with_typos:
    prompt = f"""Fix the spelling mistake in the following word: {word}
    Provide only the word.
    """
    correct_word = get_llm_response(prompt)

    words_without_typos.append(correct_word)

print(words_without_typos)
# Out:
# ['Apple', 'Whether', 'Newspaper']
