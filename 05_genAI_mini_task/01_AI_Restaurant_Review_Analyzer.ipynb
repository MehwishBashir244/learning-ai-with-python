# %%
# AI Restaurant Review Analyzer

from helper_functions import get_llm_response

review = input("Enter your restaurant review: ")

prompt = f"""
Analyze this restaurant review:

{review}

Give me:

1. Sentiment: Positive, Negative, or Neutral
2. Short summary
3. Rating out of 5
4. A polite restaurant response
"""

response = get_llm_response(prompt)

print("\n===== AI REVIEW ANALYSIS =====")
print(response)
# Out:
# Enter your restaurant review: The food was delicious and the staff was friendly, but I had to wait 30 minutes.
#
# ===== AI REVIEW ANALYSIS =====
# 1. Sentiment: Mixed (leaning Positive)
# 2. Short summary: The reviewer enjoyed the food and staff but was frustrated by a long wait time.
# 3. Rating out of 5: 3.5
# 4. Polite restaurant response: Thank you for your kind words about our food and staff. We apologize for the wait and appreciate your patience. We hope to serve you even better next time.
