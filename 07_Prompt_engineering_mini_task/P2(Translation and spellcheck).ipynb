# %%
# translating text into differnt languages

prompt = f"""
Translate the following English text to Korean, arabic, urdu:```Hi, I would like to order a resin keychain```
"""
response = get_ai_response(prompt)
print(response)
# Out:
# Korean: 안녕하세요, 나는 수지 키링을 주문하고 싶어요
# Arabic: مرحبًا ، أود طلب سلسلة مفاتيح من الراتنج
# Urdu: ہیلو، میں ریزن کی چین کی آرڈر دینا چاہتا ہوں۔

# %%
#  checking which language is this

prompt = f"""
Tell me which language this is: 
```Combien coûte le lampadaire?```
```مرحبًا ، أود طلب سلسلة مفاتيح من الراتنج?```
"""
response = get_ai_response(prompt)
print(response)
# Out:
# The first sentence is in French and it translates to "How much does the street lamp cost?"
# The second sentence is in Arabic and it translates to "Hello, I would like to order a resin keychain."

# %%
user_messages = [
  "Resin art is a creative craft that uses resin to create beautiful decorative pieces.", 
  "ریزن آرٹ ایک تخلیقی فن ہے جس میں ریزن سے خوبصورت اور منفرد اشیاء بنائی جاتی ہیں",              
  "El arte con resina es una técnica creativa para crear piezas hermosas y únicas.",                                
  "L’art en résine est une activité créative qui permet de créer des pièces magnifiques et uniques.",                            
  "فن الراتنج هو حرفة إبداعية تُستخدم لصنع قطع جميلة وفريدة من نوعه"                                              
] 

for text in user_messages:
    prompt = f"Tell me what language this is: ```{text}```"
    lang = get_ai_response(prompt)
    print(f"Original message ({lang}): {text}")
    
    response = get_ai_response(prompt)
    print(response, "\n")
# Out:
# Original message (English): Resin art is a creative craft that uses resin to create beautiful decorative pieces.
# English
#
# Original message (This is Urdu language.): ریزن آرٹ ایک تخلیقی فن ہے جس میں ریزن سے خوبصورت اور منفرد اشیاء بنائی جاتی ہیں
# This is Urdu language.
#
# Original message (This is Spanish.): El arte con resina es una técnica creativa para crear piezas hermosas y únicas.
# This is Spanish.
#
# Original message (French): L’art en résine est une activité créative qui permet de créer des pièces magnifiques et uniques.
# French
#
# Original message (This is Arabic.): فن الراتنج هو حرفة إبداعية تُستخدم لصنع قطع جميلة وفريدة من نوعه
# This is Arabic.

# %%
for text in user_messages:
    prompt = f"""
    Translate the following  text to Korean: ```{text}```
    """
    response = get_ai_response(prompt)
    print(response, "\n")
# Out:
# 수지 예술은 아름다운 장식품을 만들기 위해 수지를 사용하는 창의적인 공예입니다.
#
# "레진 아트는 레진으로 아름다운 독특한 물건을 만드는 창조적인 예술입니다."
#
# 수지 예술은 아름답고 독특한 작품을 만드는 창의적인 기술입니다.
#
# 수지 예술은 아름답고 독특한 작품을 만들 수 있는 창의적인 활동입니다.
#
# 수지 예술은 아름답고 독특한 작품을 만드는 창의적인 공예입니다.

# %%
# Tone Transformation

prompt = f"""
Translate the following from slang to a business letter: 
'Dude, This is Sana, check out this spec on this resin key chain.'
"""
response = get_ai_response(prompt)
print(response)
# Out:
# Dear Sir/Madam,
#
# I am writing to bring to your attention a specification for a resin key chain. Please review the details provided.
#
# Sincerely,
# Sana

# %%
# Spellcheck

text = [ 
  "Resin art is a cretive and beautiful art form.",
  "It uses epoxy resin to make uniqe decorative items..",
  "Common products include keychains, coasters, and jewelry.", 
  "Resin pieces are usually colorful and glosy..",
]

for t in text:
    prompt = f"""Proofread and correct the following text
    and rewrite the corrected version:
    ```{t}```"""
    response = get_ai_response(prompt)
    print(response)
# Out:
# Resin art is a creative and beautiful art form.
# It uses epoxy resin to make unique decorative items.
# Corrected version:
# Common products include keychains, coasters, and jewelry.
# Resin pieces are usually colorful and glossy.
