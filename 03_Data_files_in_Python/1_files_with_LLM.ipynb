# %%
from helper_functions import get_llm_response
from IPython.display import display, Markdown

# Write a list of ingredients
ingredients = ['chicken', 'broccoli', 'rice']

# Write the prompt
prompt = f"""
    Create a short recipe that uses the following ingredients:
    {ingredients}
"""

# Get the response from the LLM
response = get_llm_response(prompt)

# Print the LLM response
print(response)
# Out:
# Chicken and Broccoli Rice Bowl
#
# 1. Cook 1 cup of rice according to package instructions.
# 2. In a pan, sauté diced chicken until browned and cooked through.
# 3. Add chopped broccoli to the pan and cook until tender.
# 4. Mix the cooked rice into the pan with chicken and broccoli.
# 5. Season with salt, pepper, and soy sauce to taste.
# 6. Serve hot.

# %%
f = open("email.txt", "r")
email = f.read()
f.close()

# %%
print(email)
# Out:
# Subject: My Incredible Journey Around the World!
#
# Hi Andrew,
#
# I hope you are doing greatl! I just returned from an incredible trip around the world. I started in New York, enjoying a Broadway show and the skyline. In Rio de Janeiro, I soaked up the sun on Copacabana Beach and hiked to Christ the Redeemer. Cape Town amazed me with its natural beauty and safari adventures. Paris was magical with its charming streets and delicious food. Istanbul's Hagia Sophia and Bosphorus cruise were unforgettable. Tokyo dazzled with its neon lights and delicious sushi. Finally, Sydney's Opera House and Bondi Beach were the perfect end to my journey. Can't wait to share more stories and photos when we catch up!
#
# Best,
#
# Daniel

# %%
prompt = f"""Extract bullet points from the following email. 
Include the sender information. 

Email:
{email}"""

print(prompt)
# Out:
# Extract bullet points from the following email.
# Include the sender information.
#
# Email:
# Subject: My Incredible Journey Around the World!
#
# Hi Andrew,
#
# I hope you are doing greatl! I just returned from an incredible trip around the world. I started in New York, enjoying a Broadway show and the skyline. In Rio de Janeiro, I soaked up the sun on Copacabana Beach and hiked to Christ the Redeemer. Cape Town amazed me with its natural beauty and safari adventures. Paris was magical with its charming streets and delicious food. Istanbul's Hagia Sophia and Bosphorus cruise were unforgettable. Tokyo dazzled with its neon lights and delicious sushi. Finally, Sydney's Opera House and Bondi Beach were the perfect end to my journey. Can't wait to share more stories and photos when we catch up!
#
# Best,
#
# Daniel

# %%
bullet_points = get_llm_response(prompt)
print(bullet_points)
# Out:
# Sender: Daniel
#
# - Returned from an incredible trip around the world
# - Started in New York: enjoyed a Broadway show and the skyline
# - In Rio de Janeiro: relaxed on Copacabana Beach and hiked to Christ the Redeemer
# - Cape Town: experienced natural beauty and safari adventures
# - Paris: enjoyed charming streets and delicious food
# - Istanbul: visited Hagia Sophia and took a Bosphorus cruise
# - Tokyo: saw neon lights and ate delicious sushi
# - Sydney: visited Opera House and Bondi Beach
# - Looking forward to sharing more stories and photos with Andrew

# %%
# Print in Markdown format
display(Markdown(bullet_points))
# Out:
# Sender: Daniel
#
# - Returned from an incredible trip around the world
# - Started in New York: enjoyed a Broadway show and the skyline
# - In Rio de Janeiro: relaxed on Copacabana Beach and hiked to Christ the Redeemer
# - Cape Town: experienced natural beauty and safari adventures
# - Paris: enjoyed charming streets and delicious food
# - Istanbul: visited Hagia Sophia and took a Bosphorus cruise
# - Tokyo: saw neon lights and ate delicious sushi
# - Sydney: visited Opera House and Bondi Beach
# - Looking forward to sharing more stories and photos with Andrew

# %%
# Complete the code below to identify all of the countries mentioned in the email

prompt = f"""list down all the countries mentioned 
in the email

Email:
{email}
"""

countries = get_llm_response(prompt)
print(countries)
# Out:
# The countries mentioned in the email are:
#
# 1. United States (New York)
# 2. Brazil (Rio de Janeiro)
# 3. South Africa (Cape Town)
# 4. France (Paris)
# 5. Turkey (Istanbul)
# 6. Japan (Tokyo)
# 7. Australia (Sydney)

# %%
# Write code below to list all of the activities that Daniel did on his trip. You'll need to create a prompt and use get_llm_response.
prompt = f"""list down all of the activities that Daniel did on his trip
Email:
{email}
"""

activities = get_llm_response(prompt)
print(activities)
# Out:
# - Enjoyed a Broadway show in New York
# - Viewed the New York skyline
# - Soaked up the sun on Copacabana Beach in Rio de Janeiro
# - Hiked to Christ the Redeemer in Rio de Janeiro
# - Experienced safari adventures in Cape Town
# - Explored Paris's charming streets and enjoyed delicious food
# - Visited Hagia Sophia in Istanbul
# - Took a Bosphorus cruise in Istanbul
# - Enjoyed neon lights and sushi in Tokyo
# - Visited Sydney's Opera House
# - Relaxed at Bondi Beach in Sydney
