# %%
# Built-in packages

#The math package

import math

print(f"The square of {25} is",math.sqrt(25))
# Out:
# The square of 25 is 5.0

# %%
print(f"The power is", math.pow(2, 3))
# Out:
# The power is 8.0

# %%
print(f"The factorial is", math.factorial(5))
# Out:
# The factorial is 120

# %%
print(math.ceil(4.2))
print(math.floor(4.8))
# Out:
# 5
# 4

# %%
from math import cos, sin, pi

print(pi)
print(math.sin(math.pi / 2))
print(math.cos(0))
# Out:
# 3.141592653589793
# 1.0
# 1.0

# %%
# Calculating useful statistics with statistics
import statistics

numbers = [10, 20, 30, 40, 50]

print(f"The mean of the number is", statistics.mean(numbers))
# Out:
# The mean of the number is 30

# %%
# random package
# It generates random numbers and selects random elements from a list.

from random import sample

spices = ["cumin", "turmeric", "oregano", "paprika"]
vegetables = ["lettuce", "tomato", "carrot", "broccoli"]
proteins = ["chicken", "tofu", "beef", "fish", "tempeh"]

random_spices = sample(spices, 2)
random_vegetables = sample(vegetables, 2)
random_protein = sample(proteins, 1)

print(random_protein)
print(random_spices)
# Out:
# ['tempeh']
# ['cumin', 'oregano']

# %%
from helper_functions import get_llm_response

prompt = f"""Please suggest a recipe that includes the following ingredients. Spices: {random_spices} Vegetables: {random_vegetables} Proteins: {random_protein}"""

recipe = get_llm_response(prompt)
print(recipe)
# Out:
# Try a Spiced Tempeh and Broccoli Stir-Fry:
#
# Ingredients:
# - Tempeh (cubed)
# - Broccoli florets
# - Tomato (diced)
# - Cumin
# - Oregano
# - Olive oil
# - Garlic (optional)
# - Salt and pepper
#
# Instructions:
# 1. Heat olive oil in a pan over medium heat.
# 2. Add cubed tempeh and cook until golden brown.
# 3. Add minced garlic if using, then add broccoli florets; sauté for 5 minutes.
# 4. Stir in diced tomato, cumin, oregano, salt, and pepper.
# 5. Cook until broccoli is tender and tomatoes soften.
# 6. Serve hot, optionally with rice or bread.
